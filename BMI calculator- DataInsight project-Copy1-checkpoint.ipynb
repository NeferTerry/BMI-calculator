# %%
print('what is your height in centimetres ?')
# Out:
# what is your height in centimetres ?

# %%
cm = int(input())
# Out:
# 155

# %%
print('what is your weight in kilograms ?')
# Out:
# what is your weight in kilograms ?

# %%
kg = int(input())
# Out:
# 57

# %%
BMI = kg * 10000/(cm*cm)

# %%
print('Your BMI is ' + str(BMI))
# Out:
# Your BMI is 23.72528616024974

# %%
#print('Do you need an interpretation ? Type 1 for yes and 0 for no')

# %%
#ans = input()

# %%
if BMI < 18.5:
    print("Status: Underweight")
elif BMI >= 18.5 and BMI < 25:
    print("Status: Normal weight")
elif BMI >= 25 and BMI < 30:
    print("Status: Overweight")
else: 
    print("Status: Obese")
# Out:
# Status: Normal weight
